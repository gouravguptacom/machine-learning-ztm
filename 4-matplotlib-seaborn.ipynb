# %%
# Why Matplotlib?

# - Build on Numpy arrays (and Python)
# - Integrates directly with pandas
# - Can create basic or advanced plots
# - Simple to use interface (once you get the foundations)

# %%
# What we'll cover?

# - Matplotlib workflow
# - Importing Matplotlib and the 2 ways of plaotting
# - Plotting data from NumPy arrays
# - Plotting data from pandas DataFrames
# - Customizing plots
# - Saving and sharing plot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);

# %%
# 1st method
fig = plt.figure() # creates a figure
ax = fig.add_subplot() # adds some axis
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y) # add some data
plt.show()

# %%
# 3rd method (recommanded)
fig, ax = plt.subplots() # this resets the previous ploted data
ax.plot(x, y); # add some data
